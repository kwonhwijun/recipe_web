# %% [markdown]
# # 약 상호작용 전처리

# %%
import pandas as pd

# %%
nonna_info = pd.read_csv(r'C:\Users\USER\Desktop\nonna_info.csv')

# %%
nonna_info
# Out:
#       Unnamed: 0                                    sunb_name  \
# 0              5             이토프리드염산염(Itopride Hydrochloride)
# 1              6  모사프리드시트르산염이수화물(Mosapride Citrate Dihydrate)
# 2              9                            오메프라졸(Omeprazole)
# 3             10                            오메프라졸(Omeprazole)
# 4             11                            오메프라졸(Omeprazole)
# ...          ...                                          ...
# 1135       15407          티클로피딘염산염(Ticlopidine Hydrochloride)
# 1136       15408          티클로피딘염산염(Ticlopidine Hydrochloride)
# 1137       15409          티클로피딘염산염(Ticlopidine Hydrochloride)
# 1138       15410          티클로피딘염산염(Ticlopidine Hydrochloride)
# 1139       15413             베탁솔롤염산염(Betaxolol Hydrochloride)
#
#                                         contents_origin ingd_code
# 0                             식전 30분~1시간 또는 식후에 복용하세요.    I005050
# 1                                  식사와 관계없이 복용할 수 있어요.    I002400
# ...

# %%
filtered_rows = nonna_info[~nonna_info['contents_origin'].str.contains('식전 30분~1시간 또는 식후에 복용하세요. |식사와 관계없이 복용할 수 있어요. |식전 30분~1시간에 복용하는 것이 가장 좋아요. ')]

# %%
filtered_rows
# Out:
#       Unnamed: 0                            sunb_name  \
# 3             10                    오메프라졸(Omeprazole)
# 4             11                    오메프라졸(Omeprazole)
# 5             12                    오메프라졸(Omeprazole)
# 6             13                    오메프라졸(Omeprazole)
# 7             14                    오메프라졸(Omeprazole)
# ...          ...                                  ...
# 1135       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 1136       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 1137       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 1138       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
# 1139       15413     베탁솔롤염산염(Betaxolol Hydrochloride)
#
#                                         contents_origin ingd_code
# 3     음주와 흡연을 삼가세요. 알코올과 니코틴은 위벽을 자극하여 위궤양, 가슴쓰림, 위산...   I002684
# 4     {{카페인}} 복용시 주의하세요. 카페인은 하부식도괄약근을 느슨하게 하여 위산역류 ...   I002684
# 5     마늘, 양파 등 자극성이 강한 식품은 위장장애를 유발하여 약효를 상쇄시킬 수 있으니...   I002684
# ...

# %%
filtered_rows2 = filtered_rows[~filtered_rows['contents_origin'].str.contains('음주|흡연')]

# %%
filtered_rows2
# Out:
#       Unnamed: 0                            sunb_name  \
# 4             11                    오메프라졸(Omeprazole)
# 5             12                    오메프라졸(Omeprazole)
# 6             13                    오메프라졸(Omeprazole)
# 7             14                    오메프라졸(Omeprazole)
# 8             15                    오메프라졸(Omeprazole)
# ...          ...                                  ...
# 1133       15384          메틸도파수화물(Methyldopa Hydrate)
# 1135       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 1136       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 1137       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 1138       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                         contents_origin ingd_code
# 4     {{카페인}} 복용시 주의하세요. 카페인은 하부식도괄약근을 느슨하게 하여 위산역류 ...   I002684
# 5     마늘, 양파 등 자극성이 강한 식품은 위장장애를 유발하여 약효를 상쇄시킬 수 있으니...   I002684
# 6      이 약은 비타민 B의 고갈을 일으킬 수 있어요. 보충제의 복용이 도움을 줄 수 있어요.   I002684
# ...

# %%
filtered_rows2.loc[filtered_rows2['contents_origin'].str.contains('{{카페인}}'), 'contents_origin'] = '카페인 복용시 주의'

# %%
filtered_rows2
# Out:
#       Unnamed: 0                            sunb_name  \
# 4             11                    오메프라졸(Omeprazole)
# 5             12                    오메프라졸(Omeprazole)
# 6             13                    오메프라졸(Omeprazole)
# 7             14                    오메프라졸(Omeprazole)
# 8             15                    오메프라졸(Omeprazole)
# ...          ...                                  ...
# 1133       15384          메틸도파수화물(Methyldopa Hydrate)
# 1135       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 1136       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 1137       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 1138       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                         contents_origin ingd_code
# 4                                            카페인 복용시 주의   I002684
# 5     마늘, 양파 등 자극성이 강한 식품은 위장장애를 유발하여 약효를 상쇄시킬 수 있으니...   I002684
# 6      이 약은 비타민 B의 고갈을 일으킬 수 있어요. 보충제의 복용이 도움을 줄 수 있어요.   I002684
# ...

# %%
filtered_rows2[filtered_rows2['contents_origin'].str.contains('마늘, 양파')]
# Out:
#       Unnamed: 0                          sunb_name  \
# 41            99  라니티딘염산염(Ranitidine Hydrochloride)
# 61           162                   파모티딘(Famotidine)
# 270          695                   시메티딘(Cimetidine)
# 357        12990                   니자티딘(Nizatidine)
# 1083       15192  시메티딘염산염(Cimetidine Hydrochloride)
#
#                                         contents_origin ingd_code
# 41    마늘, 양파 등 자극성이 강한 식품은 위장장애를 유발하여 이 약의 효과를 상쇄시킬 ...   I003478
# 61    마늘, 양파 등 자극성이 강한 식품은 위장장애를 유발하여 이 약의 효과를 상쇄시킬 ...   I001401
# 270   마늘, 양파 등 자극성이 강한 식품은 위장장애를 유발하여 이 약의 효과를 상쇄시킬 ...   I004695
# 357   마늘, 양파 등 자극성이 강한 식품은 위장장애를 유발하여 이 약의 효과를 상쇄시킬 ...   I002592
# 1083  마늘, 양파 등 자극성이 강한 식품은 위장장애를 유발하여 이 약의 효과를 상쇄시킬 ...   I004696

# %%
filtered_rows2.loc[filtered_rows2['contents_origin'].str.contains('마늘, 양파'), 'contents_origin'] = '마늘, 양파 등 자극성이 강한 식품은 섭취에 주의'

# %%
filtered_rows2[filtered_rows2['contents_origin'].str.contains('마늘, 양파')]
# Out:
#       Unnamed: 0                                          sunb_name  \
# 5             12                                  오메프라졸(Omeprazole)
# 13            20                        탄산수소나트륨(Sodium Bicarbonate)
# 41            99                  라니티딘염산염(Ranitidine Hydrochloride)
# 61           162                                   파모티딘(Famotidine)
# 132          394                                란소프라졸(Lansoprazole)
# 202          538  에스오메프라졸마그네슘이수화물(Esomeprazole Magnesium Dihydrate)
# 270          695                                   시메티딘(Cimetidine)
# 277          715  에스오메프라졸마그네슘삼수화물(Esomeprazole Magnesium Trihydr...
# 311        12881                       라베프라졸나트륨(Rabeprazole Sodium)
# 320        12918  판토프라졸나트륨세스키히드레이트(Pantoprazole Sodium Sesquihyd...
# 357        12990                                   니자티딘(Nizatidine)
# 369        13013                              에스오메프라졸(Esomeprazole)
# 377        13022  에스오메프라졸스트론튬사수화물(Esomeprazole Strontium Tetrahy...
# ...

# %%
filtered_rows2.loc[filtered_rows2['contents_origin'].str.contains('비타민 B의 고갈'), 'contents_origin'] = '비타민 B의 고갈'

# %%
filtered_rows2[filtered_rows2['contents_origin'].str.contains('이 약은 식품이나 칼슘 보충제로부터의 칼슘 흡수를 저해하므로 골다공증에 주의하세요.')]
# Out:
#      Unnamed: 0                                          sunb_name  \
# 7            14                                  오메프라졸(Omeprazole)
# 134         396                                란소프라졸(Lansoprazole)
# 204         540  에스오메프라졸마그네슘이수화물(Esomeprazole Magnesium Dihydrate)
# 279         717  에스오메프라졸마그네슘삼수화물(Esomeprazole Magnesium Trihydr...
# 313       12883                       라베프라졸나트륨(Rabeprazole Sodium)
# 322       12920  판토프라졸나트륨세스키히드레이트(Pantoprazole Sodium Sesquihyd...
# 371       13015                              에스오메프라졸(Esomeprazole)
# 379       13024  에스오메프라졸스트론튬사수화물(Esomeprazole Strontium Tetrahy...
# 388       13047                    에스오메프라졸나트륨(Esomeprazole Sodium)
# 699       13962                           덱스란소프라졸(Dexlansoprazole)
#
#                                     contents_origin ingd_code
# 7    이 약은 식품이나 칼슘 보충제로부터의 칼슘 흡수를 저해하므로 골다공증에 주의하세요.   I002684
# 134  이 약은 식품이나 칼슘 보충제로부터의 칼슘 흡수를 저해하므로 골다공증에 주의하세요.   I005114
# ...

# %%
filtered_rows2.loc[filtered_rows2['contents_origin'].str.contains('이 약은 식품이나 칼슘 보충제로부터의 칼슘 흡수를 저해하므로 골다공증에 주의하세요.'), 'contents_origin'] = '칼슘 흡수를 저해'

# %%
filtered_rows3 = filtered_rows2[~filtered_rows2['contents_origin'].str.contains('캡슐')]

# %%
filtered_rows3
# Out:
#       Unnamed: 0                            sunb_name  \
# 4             11                    오메프라졸(Omeprazole)
# 5             12                    오메프라졸(Omeprazole)
# 6             13                    오메프라졸(Omeprazole)
# 7             14                    오메프라졸(Omeprazole)
# 10            17          탄산수소나트륨(Sodium Bicarbonate)
# ...          ...                                  ...
# 1133       15384          메틸도파수화물(Methyldopa Hydrate)
# 1135       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 1136       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 1137       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 1138       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                         contents_origin ingd_code
# 4                                            카페인 복용시 주의   I002684
# 5                           마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 6                                             비타민 B의 고갈   I002684
# ...

# %%
filtered_rows3.to_csv('C:/Users/User/filtered_rows3.csv', index=False)

# %%
filtered_rows3 = pd.read_csv(r'C:/Users/User/Desktop/filtered_rows3.csv')

# %%
filtered_rows3
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            17          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 778       15384          메틸도파수화물(Methyldopa Hydrate)
# 779       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 780       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 781       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 782       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows3[filtered_rows3['contents_origin'].str.contains('공복')]
# Out:
#      Unnamed: 0                                          sunb_name  \
# 4            17                        탄산수소나트륨(Sodium Bicarbonate)
# 33          140                     트리메부틴말레산염(Trimebutine Maleate)
# 43          171  메토클로프라미드염산염수화물(Metoclopramide Hydrochloride Hy...
# 45          180                      수크랄페이트수화물(Sucralfate Hydrate)
# 49          232                                차전자피(Psyllium Husk)
# 53          236                                    비사코딜(Bisacodyl)
# 70          285                            푸마르산철(Ferrous Fumarate)
# 117         493                     건조황산제일철(Dried Ferrous Sulfate)
# 125         521                                  실로스타졸(Cilostazol)
# 184         680                                 차전자(Plantago Seed)
# 207       12833                    황산철수화물(Ferrous Sulfate Hydrate)
# 319       13255                   미코페놀레이트나트륨(Mycophenolate Sodium)
# 340       13334                                보리코나졸(Voriconazole)
# ...

# %%
filtered_rows3 = filtered_rows3[~filtered_rows3['contents_origin'].str.contains('공복') | filtered_rows3['sunb_name'].str.contains('펠로디핀')]

# %%
filtered_rows3[filtered_rows3['contents_origin'].str.contains('공복')]
# Out:
#      Unnamed: 0         sunb_name  \
# 582       14422  펠로디핀(Felodipine)
#
#                                        contents_origin ingd_code
# 582  고지방/고탄수화물 식사는 이 약의 혈중농도를 60% 정도 높일 수 있습니다. 공복 ...   I001414

# %%
filtered_rows3
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 5            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 778       15384          메틸도파수화물(Methyldopa Hydrate)
# 779       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 780       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 781       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 782       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows3[filtered_rows3['contents_origin'].str.contains('술')]
# Out:
#      Unnamed: 0                                          sunb_name  \
# 65          265                             아세트아미노펜(Acetaminophen)
# 77          307                                   세레콕시브(Celecoxib)
# 173         608                                     나프록센(Naproxen)
# 177         613                                   이부프로펜(Ibuprofen)
# 220       12866                        디클로페낙나트륨(Diclofenac Sodium)
# 235       12945                           나프록센나트륨(Naproxen Sodium)
# 247       12971            디클로페낙디에틸암모늄(Diclofenac Diethylammonium)
# 295       13104                                      아스피린(Aspirin)
# 328       13268                         이부프로펜나트륨(Ibuprofen Sodium)
# 358       13413  디클로페낙β-디메틸아미노에탄올(Diclofenac β-dimethylaminoeth...
# 384       13537                                  디클로페낙(Diclofenac)
# 433       13752                                  케토프로펜(Ketoprofen)
# 471       13918                        이부프로펜피코놀(Ibuprofen piconol)
# ...

# %%
filtered_rows3 = filtered_rows3[~filtered_rows3['contents_origin'].str.contains('술')]

# %%
filtered_rows3
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 5            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 778       15384          메틸도파수화물(Methyldopa Hydrate)
# 779       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 780       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 781       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 782       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows3.to_csv('C:/Users/User/filtered_rows4.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 filtered_rows3.to_csv('C:/Users/User/filtered_rows4.csv', index=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
# ...

# %%
filtered_rows4 = pd.read_csv(r'C:/Users/User/filtered_rows4.csv')

# %%
filtered_rows4
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 721       15384          메틸도파수화물(Methyldopa Hydrate)
# 722       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 723       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 724       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 725       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows4[filtered_rows4['contents_origin'].str.contains('철분 보충제')]
# Out:
#      Unnamed: 0                                  sunb_name  \
# 6            21                탄산수소나트륨(Sodium Bicarbonate)
# 189         727                        L-카르니틴(L-Carnitine)
# 282       13119              에티드론산나트륨(Etidronate Disodium)
# 349       13515  파미드론산나트륨수화물(Pamidronate Disodium Hydrate)
# 721       15384                메틸도파수화물(Methyldopa Hydrate)
#
#                                contents_origin ingd_code
# 6    철분 보충제를 복용시 이 약과 최소 2시간의 시간 간격을 두고 복용하세요.   I003757
# 189            철분 보충제 복용시 이 약의 흡수가 저해될 수 있어요.    I006336
# 282         마그네슘/칼슘/철분 보충제, 제산제 복용시 시간간격을 두세요.   I001048
# 349         마그네슘/칼슘/철분 보충제, 제산제 복용시 시간간격을 두세요.   I001054
# 721            철분 보충제 복용시 이 약의 흡수가 저해될 수 있어요.    I002237

# %%
filtered_rows4 = filtered_rows4[~filtered_rows4['contents_origin'].str.contains('철분 보충제')]

# %%
filtered_rows4
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 720       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 722       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 723       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 724       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 725       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows4 = filtered_rows4[~filtered_rows4['contents_origin'].str.contains('마그네슘 또는 알루미늄 함유 제산제 또는 마그네슘 보충제 복용시 이 약과 최소 2시간의 시간 간격을 두고 복용하세요.')]

# %%
filtered_rows4 = filtered_rows4[~filtered_rows4['contents_origin'].str.contains('이 약을 복용하는 동안 입이 마를 수 있어요. 충분한 물을 자주 섭취하세요.')]

# %%
filtered_rows4 = filtered_rows4[~filtered_rows4['contents_origin'].str.contains('위장장애가 생기면 음식과 함께 복용하세요.')]

# %%
filtered_rows4
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 720       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 722       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 723       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 724       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 725       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows4[filtered_rows4['contents_origin'].str.contains('대량의 자몽주스 섭취를 피하세요. 이 약의 대사가 저해되고 부작용이 심해질 수 있어요. ')]
# Out:
#      Unnamed: 0                                          sunb_name  \
# 11           81       아토르바스타틴칼슘무수물(Atorvastatin Calcium Anhydrous)
# 72          332         아토르바스타틴칼슘수화물(Atorvastatin Calcium Hydrate)
# 117         526                                 심바스타틴(Simvastatin)
# 598       14706  아토르바스타틴스트론튬오수화물(Atorvastatin Strontium Pentahy...
# 600       14712                                  로바스타틴(Lovastatin)
#
#                                        contents_origin ingd_code
# 11   대량의 자몽주스 섭취를 피하세요. 이 약의 대사가 저해되고 부작용이 심해질 수 있어요.    I012151
# 72   대량의 자몽주스 섭취를 피하세요. 이 약의 대사가 저해되고 부작용이 심해질 수 있어요.    I004369
# 117  대량의 자몽주스 섭취를 피하세요. 이 약의 대사가 저해되고 부작용이 심해질 수 있어요.    I003721
# 598  대량의 자몽주스 섭취를 피하세요. 이 약의 대사가 저해되고 부작용이 심해질 수 있어요.    I012283
# 600  대량의 자몽주스 섭취를 피하세요. 이 약의 대사가 저해되고 부작용이 심해질 수 있어요.    I001927

# %%
filtered_rows4.loc[filtered_rows4['contents_origin'].str.contains('대량의 자몽주스 섭취를 피하세요.'), 'contents_origin'] = '자몽주스 섭취 피하세요.'

# %%
filtered_rows4
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 720       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 722       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 723       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 724       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 725       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows4 = filtered_rows4[~filtered_rows4['contents_origin'].str.contains('식사와 관계없이 복용하거나, 위장장애를 줄이기 위해 식후에 복용할 수 있어요.|식사와 함께 복용하세요. 이 약을 빈 속에 복용시 위장장애가 심해질 수 있어요.')]

# %%
filtered_rows4.loc[filtered_rows4['contents_origin'].str.contains('감자, 흰 빵과 같은 고탄수화물 식품은 혈당수준을 상승시켜 이 약의 필요 용량을 증가시킬 수 있어요. '), 'contents_origin'] = '고탄수화물 식품은 약의 필요 용량 증가.'

# %%
filtered_rows4
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 720       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 722       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 723       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 724       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 725       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows4 = filtered_rows4[~filtered_rows4['contents_origin'].str.contains('알로에 주스는 혈당을 강하시키는 작용이 뛰어나기 때문에 이 약과 병용시 저혈당증의 위험성이 있어요.')]

# %%
filtered_rows4
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 720       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 722       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 723       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 724       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 725       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows4.to_csv('C:/Users/User/filtered_rows5.csv', index=False)

# %%
filtered_rows5 = pd.read_csv(r'C:/Users/User/filtered_rows5.csv')

# %%
filtered_rows5
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 674       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 675       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 676       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 677       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 678       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows5[filtered_rows5['contents_origin'].str.contains('시간 간격')]
# Out:
#      Unnamed: 0                                  sunb_name  \
# 10           89          메트포르민염산염(Metformin Hydrochloride)
# 13           95          라니티딘염산염(Ranitidine Hydrochloride)
# 14           96          라니티딘염산염(Ranitidine Hydrochloride)
# 27          158                           파모티딘(Famotidine)
# 28          159                           파모티딘(Famotidine)
# 35          181              수크랄페이트수화물(Sucralfate Hydrate)
# 39          234                        차전자피(Psyllium Husk)
# 47          246                        글리메피리드(Glimepiride)
# 61          314                    탄산칼슘(Calcium Carbonate)
# 141         595      피오글리타존염산염(Pioglitazone Hydrochloride)
# 158         682                         차전자(Plantago Seed)
# 160         691                           시메티딘(Cimetidine)
# 161         692                           시메티딘(Cimetidine)
# 217       12986                           니자티딘(Nizatidine)
# 218       12987                           니자티딘(Nizatidine)
# ...

# %%
filtered_rows5 = filtered_rows5[~filtered_rows5['contents_origin'].str.contains('시간 간격') | filtered_rows3['sunb_name'].str.contains('탄산칼슘|페니토인나트륨|레보티록신나트륨수화물')]
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10612\1271678703.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_rows5 = filtered_rows5[~filtered_rows5['contents_origin'].str.contains('시간 간격') | filtered_rows3['sunb_name'].str.contains('탄산칼슘|페니토인나트륨|레보티록신나트륨수화물')]

# %%
filtered_rows5
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 674       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 675       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 676       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 677       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 678       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows5['contents_origin'].value_counts()
# Out:
# 카페인 복용시 주의                                                                      83
# 식사와 관계없이 복용할 수 있어요.                                                             40
# 마늘, 생강, 인삼, 은행엽은 피를 묽게 하여 출혈의 위험성을 높일 수 있으니 과량 섭취에 주의하세요.                       22
# 위장장애가 있을 시, 식사와 함께 복용할 수 있어요.                                                   20
# 마늘, 양파 등 자극성이 강한 식품은 섭취에 주의                                                     16
#                                                                                 ..
# 이 약을 장기복용시 혈중 칼슘 또는 비타민 D의 농도가 낮아질 수 있어요. 칼슘 또는 비타민 D 보충제의 복용이 도움이 될 수 있어요.      1
# 이 약을 복용시 혈중 엽산 농도가 낮아질 수 있어요. 엽산 보충제의 복용이 도움이 될 수 있어요.                           1
# 임산부가 이 약을 복용시 신생아는 심각한 비타민 K의 부족이 있을 수 있어요. 분만 전 임산부의 비타민 K 보충을 권해요.             1
# 철분은 이 약의 흡수를 1/10까지 감소시키므로 함께 복용하지 마세요. 함께 복용할 경우, 이 약과 3시간 이상의 시간간격을 두세요.       1
# 이 약은 식사를 할 시 복용하고, 식사를 거를 시에는 복용하지 않아요.                                          1
# Name: contents_origin, Length: 244, dtype: int64

# %%
filtered_rows5 = filtered_rows5[~filtered_rows5['contents_origin'].str.contains('식사와 관계없이 복용할 수 있어요.')]

# %%
filtered_rows5
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 674       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 675       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 676       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 677       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 678       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows5[filtered_rows5['contents_origin'].str.contains('녹차, 아스파라거스')]
# Out:
#      Unnamed: 0                                     sunb_name  \
# 9            88             메트포르민염산염(Metformin Hydrochloride)
# 46          245                           글리메피리드(Glimepiride)
# 140         594         피오글리타존염산염(Pioglitazone Hydrochloride)
# 224       13006                             인다파미드(Indapamide)
# 369       13724                              글리피지드(Glipizide)
# 371       13727                             푸로세미드(Furosemide)
# 393       13806              톨터로딘타르타르산염(Tolterodine Tartrate)
# 437       14029                 옥시부티닌염산염(Oxybutynin Chloride)
# 476       14235  아밀로리드염산염수화물(Amiloride Hydrochloride Hydrate)
# 503       14412                              토르세미드(Torsemide)
# 560       14694                                아카보즈(Acarbose)
# 597       14832                        스피로노락톤(Spironolactone)
#
#                                        contents_origin ingd_code
# 9    녹차, 아스파라거스 추출물, 민들레 등과 같은 천연 이뇨제는 이 약의 작용을 방해하...   I002178
# ...

# %%
filtered_rows4.loc[filtered_rows4['contents_origin'].str.contains('녹차, 아스파라거스'), 'contents_origin'] = '녹차, 아스파라거스 추출물, 민들레 등과 같은 천연 이뇨제는 약의 작용을 방해'

# %%
filtered_rows5 = filtered_rows5[~filtered_rows5['contents_origin'].str.contains('마그네슘 또는 알루미늄')]

# %%
filtered_rows5 = filtered_rows5[~filtered_rows5['contents_origin'].str.contains('식사 후 복용하세요.')]

# %%
filtered_rows5 = filtered_rows5[~filtered_rows5['contents_origin'].str.contains('이 약을 복용하는 동안 충분한 수분섭취를 유지하세요.')]

# %%
filtered_rows5 = filtered_rows5[~filtered_rows5['contents_origin'].str.contains('탄산음료 섭취를 최대한 줄이거나 피하세요.')]

# %%
filtered_rows5 = filtered_rows5[~filtered_rows5['contents_origin'].str.contains('철분이나 엽산 보충제의 흡수를 방해할 수 있으므로')]

# %%
filtered_rows5 = filtered_rows5[~filtered_rows5['contents_origin'].str.contains('시트러스 함유 식품/음료와 함께 복용하면 알루미늄의 흡수가 증가할 수 있어요. 3시간 이상 간격을 두고 복용하세요.')]

# %%
filtered_rows5 = filtered_rows5[~filtered_rows5['contents_origin'].str.contains('식전 30분~1시간에 복용하세요. ')]

# %%
filtered_rows5
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 674       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 675       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 676       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 677       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 678       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows5.to_csv('C:/Users/User/filtered_rows6.csv', index=False)

# %%
filtered_rows6 = pd.read_csv(r'C:/Users/User/filtered_rows6.csv')

# %%
filtered_rows6.loc[filtered_rows6['contents_origin'].str.contains('녹차, 아스파라거스'), 'contents_origin'] = '녹차, 아스파라거스 추출물, 민들레 등과 같은 천연 이뇨제는 약의 작용을 방해'

# %%
filtered_rows6.loc[filtered_rows6['contents_origin'].str.contains('비타민 B 12 보충이 도움이 될 수 있어요.'), 'contents_origin'] = '비타민 B 보충이 도움'

# %%
filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('충분한 물과 함께 복용하세요.')]

# %%
filtered_rows6
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 574       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 575       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 576       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 577       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 578       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('시트러스 함유 식품/음료와 함께 복용하면 알루미늄의 흡수가 증가할 수 있습니다. 3시간 이상 간격을 두고 복용하세요.')]

# %%
filtered_rows6
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 574       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 575       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 576       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 577       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 578       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows6.loc[filtered_rows6['contents_origin'].str.contains('지방이 함유된 음식과 함께 복용하면 흡수를 높일 수 있어요.'), 'contents_origin'] = '지방이 함유된 음식과 함께 복용하면 흡수를 높임'

# %%
filtered_rows6.loc[filtered_rows6['contents_origin'].str.contains('섬유질이 풍부한 음식과 함께 하루에 1.5-2 리터의 충분한 수분을 섭취하세요.'), 'contents_origin'] = '섬유질이 풍부한 음식 섭취'

# %%
filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('알약을 씹거나 부수지 말고 통째로 드세요.')]

# %%
filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('이 약의 장용코팅(장에서 녹게 하기 위함)을 보호하기 위해 복용 후 1시간 이내에 우유, 유제품을 드시지 마세요.')]
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10612\1113565475.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('이 약의 장용코팅(장에서 녹게 하기 위함)을 보호하기 위해 복용 후 1시간 이내에 우유, 유제품을 드시지 마세요.')]

# %%
filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('첫 식사 직전(또는 첫 식사와 함께) 복용하세요. 이 약을 복용 후 식사를 거르지 않아요.')]
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10612\2172062177.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('첫 식사 직전(또는 첫 식사와 함께) 복용하세요. 이 약을 복용 후 식사를 거르지 않아요.')]

# %%
filtered_rows6.loc[filtered_rows6['contents_origin'].str.contains('고탄수화물 식품은 약의 필요 용량 증가.'), 'contents_origin'] = '고탄수화물 식품은 약의 필요 용량 증가'

# %%
filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('식사와 함께 복용하면 위장장애를 줄일 수 있어요.')]

# %%
filtered_rows6.loc[filtered_rows6['contents_origin'].str.contains('고용량의 비타민 C는 이 약이 소변으로 배출되는 것을 막아 이 약의 부작용과 독성을 증가시킬 수 있어요.  이 약을 복용하는 중에 하루 3g 이상의 비타민 C 섭취를 권장하지 않아요.'), 'contents_origin'] = '3g 이상의 비타민 C 섭취를 권장하지 않아요'

# %%
filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('에키나시아와 이 약을 함께 복용할 시 민감한 사람에게는 간염을 일으킬 수도 있어요.')]

# %%
filtered_rows6
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 574       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 575       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 576       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 577       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 578       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('액상형태의 경우, 치아 색소침착을 예방하기 위해 스트로(빨대)를 이용하여 복용하는 것이 좋습니다. ')]
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10612\1312872826.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('액상형태의 경우, 치아 색소침착을 예방하기 위해 스트로(빨대)를 이용하여 복용하는 것이 좋습니다. ')]

# %%
filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('철분의 흡수를 감소시킬 수 있어요. 철분보충제와 2시간 이상의 시간간격을 두고 복용하세요. ')]

# %%
filtered_rows6.loc[filtered_rows6['contents_origin'].str.contains('30 mg의 철분을 복용할 때 200 mg 정도의 비타민 C와 함께 복용하시면 철분의 흡수가 잘됩니다.'), 'contents_origin'] = '비타민 C와 함께 복용하시면 철분의 흡수가 잘됩니다'

# %%
filtered_rows6.loc[filtered_rows6['contents_origin'].str.contains('육류/어류/가금류는 철분제의 흡수를 높여줍니다.'), 'contents_origin'] = '육류/어류/가금류는 흡수를 높여줌'

# %%
filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('탄산염 제산제, 칼슘, 인, 아연, 구리 보충제와는 2시간 이상 간격을 두고 복용하세요.')]

# %%
filtered_rows6.loc[filtered_rows6['contents_origin'].str.contains('마늘, 생강, 인삼, 은행엽은 피를 묽게 하여 출혈의 위험성을 높일 수 있으니 과량 섭취에 주의하세요.'), 'contents_origin'] = '마늘, 생강, 인삼, 은행엽은 과량 섭취에 주의'

# %%
filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('단일제, vitamin D와의 복합제 : 식사와 함께, 또는 식후 복용하세요. ')]

# %%
filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('단일제, 제산제 : 식후 1~3시간에 복용하세요.')]

# %%
filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('식사와 함께 또는 충분한 물과 함께 복용하면 식도자극을 피할 수 있어요.')]

# %%
filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('미각 또는 후각장애가 나타날 수 있어요. 충분한 영양섭취를 유지하세요.')]

# %%
filtered_rows6 = filtered_rows6[~filtered_rows6['contents_origin'].str.contains('이 약을 우유 및 유제품, 칼슘 강화 주스와 단독으로 복용하지 마세요. 칼슘이 이 약의 흡수를 방해하여 약효를 떨어뜨릴 수 있어요.')]

# %%
filtered_rows6.loc[filtered_rows6['contents_origin'].str.contains('{{칼륨이 풍부한 식단}} 또는 칼륨보충제를 복용시 저칼륨혈증에 도움을 줄 수 있어요.'), 'contents_origin'] = '칼륨이 풍부한 식단은 도움을 줌'

# %%
filtered_rows6.loc[filtered_rows6['contents_origin'].str.contains('이 약은 혈중 칼슘 농도를 증가시킬 수 있어요. 칼슘보충제나 비타민 D 보충제를 복용하기 전에 전문가와 상의하세요.'), 'contents_origin'] = '칼슘 농도를 증가 시킬 수 있음'

# %%
filtered_rows6.loc[filtered_rows6['contents_origin'].str.contains('이 약을 복용하는 동안 자몽, 자몽쥬스를 피하세요.'), 'contents_origin'] = '자몽, 자몽쥬스 피하세요'

# %%
filtered_rows6.loc[filtered_rows6['contents_origin'].str.contains('칼슘과 비타민 D를 적절히 섭취해야 해요. 칼슘/비타민 D 보충제 복용이 필요할 수 있어요. '), 'contents_origin'] = '칼슘/비타민 D 보충 필요'

# %%
filtered_rows6
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 574       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 575       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 576       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 577       15409  티클로피딘염산염(Ticlopidine Hydrochloride)
# 578       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows6.to_csv('C:/Users/User/filtered_rows7.csv', index=False)

# %%
filtered_rows7 = pd.read_csv(r'C:/Users/User/filtered_rows7.csv')

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('반드시 충분한 양의 수분\(최소 250ml의 액제\)과 함께 이 약을 복용하세요.')]

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('충분한 물과 함께 취침 전에 복용하세요. [약 250ml 이상]')]

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('이 약의 장용코팅\(장에서 녹게 하기 위함\)을 보호하기 위해 복용 후 1시간 이내에 우유, 유제품을 드시지 마세요.')]

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('첫 식사 직전\(또는 첫 식사와 함께\) 복용하세요. 이 약을 복용 후 식사를 거르지 않아요.')]

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('오트밀 또는 식이섬유가 많이 포함된 시리얼은 이 약의 흡수를 지연시켜 신속한 효과를 보지 못하게 할 수 있으니 빠른 진통효과가 필요할 시 2시간 이상의 간격을 두고 복용하세요.')]

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('마그네슘, 철분, 아연 또는 칼슘 함유 보충제 복용시 이 약 복용 최소 3시간 이전 또는 2시간 이후에 복용하세요.')]

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('아침에 식후 또는 식사\(우유\)와 함께 복용하면 위장장애를 줄일 수 있어요.')]

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('위장장애가 있을 시, 식사와 함께 복용할 수 있어요.')]

# %%
filtered_rows7.loc[filtered_rows7['contents_origin'].str.contains('마늘, 생강은 피를 묽게 하여 출혈의 위험성을 높일 수 있으니 과량 섭취에 주의하세요.'), 'contents_origin'] = '마늘, 생강은 과량 섭취에 주의'

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('유제품 또는 무기질 강화음료\(예 : 우유, 요구르트, 칼슘강화 오렌지주스\)와 함께 복용하면 이 약의 흡수가 감소하기 때문에 병용하지 않는 것이 좋아요 \(단, 식사의 일부로 섭취하는 식이성 칼슘은 상관없음\).')]

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('액상형태의 경우, 치아 색소침착을 예방하기 위해 스트로\(빨대\)를 이용하여 복용하는 것이 좋습니다. ')]

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('서방형 : 음식과 함께 복용하면 흡수가 잘 되지만, 식사와 관계없이 복용해도 됩니다.')]

# %%
filtered_rows7.loc[filtered_rows7['contents_origin'].str.contains('고지방식\(지방이 많은 식단\)에서 이 약의 흡수가 증가되므로 고지방식을 섭취하는 경우 주의하세요.'), 'contents_origin'] = '고지방식 섭취 주의'

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('적어도 식사 30분 전에 이 약을 복용하세요. 다른 약이나 건강보조식품 복용시에도 적어도 30분 먼저 이 약을 복용하세요.')]

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('이 약을 위\(stomach\)로 쉽게 도달시키고 식도 자극 가능성을 감소시키기 위해, 똑바른 자세\(upright position\)로 충분한 양의 순수한 물\(170 ∼ 240 mL\)과 함께 복용하세요. 광천수나 보리차를 포함하여 다른 음료수와 함께 복용시 이 약의 흡수를 떨어뜨릴 수 있어요. ')]

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('제산제\(칼슘,마그네슘\)\(2시간\), 칼슘보충제\(2시간\), 비타민제, 철분제\(2시간\) 등 그 어떤 의약품이나 음식물, 음료수 등 그 어떤 식품이라도 이 약 복용 30분 이내에 먹지 마세요. 이 약과 함께 침전물을 형성하여 장에서 흡수되지 않은 채 배설되어 버릴 수 있어요. ')]

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('이 약은 식사 최소 1시간 이전에 복용하세요. ')]

# %%
filtered_rows7 = filtered_rows7[~filterfiltered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('이 약을 위장으로 쉽게 도달시키고 식도자극 위험을 줄이기 위해, 똑바른 자세\(upright position\)로 충분한 양의 순수한 물\(170 ∼ 240 mL\)과 함께 복용하세요. 광천수를 포함하여 다른 음료수와 함께 복용시 이 약의 흡수를 떨어뜨릴 수 있어요. ')]ed_rows7['contents_origin'].str.contains('적어도 식사 1시간 전에 복용하세요. 다른 약이나 건강보조식품 복용시에도 적어도 1시간 먼저 이 약을 복용하세요.')]

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('이 약을 위장으로 쉽게 도달시키고 식도자극 위험을 줄이기 위해, 똑바른 자세\(upright position\)로 충분한 양의 순수한 물\(170 ∼ 240 mL\)과 함께 복용하세요. 광천수를 포함하여 다른 음료수와 함께 복용시 이 약의 흡수를 떨어뜨릴 수 있어요. ')]

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('제산제\(칼슘, 마그네슘\)\(2시간\), 칼슘보충제\(2시간\), 비타민제, 철분제\(2시간\) 등 그 어떤 의약품이나 음식물, 음료수 등 그 어떤 식품이라도 이 약 복용 60분 이내에 먹지 마세요. 이 약과 함께 침전물을 형성하여 장에서 흡수되지 않은 채 배설되어 버릴 수 있어요. ')]

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('식사와 함께 복용하면 이 약의 흡수 속도가 조절되어 혈압이 지나치게 낮아지는 것을 막을 수 있어요.')]

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('서방정 : 식후 즉시 또는 식사와 함께 복용하세요.')]

# %%
filtered_rows7.loc[filtered_rows7['contents_origin'].str.contains('과도한 비타민 A와 비타민 E의 병용시 피를 너무 묽게 할 수 있어요. 비타민 E는 하루 400IU 이하, 비타민 A는 하루 10000IU이하로 섭취하시길 권해요.'), 'contents_origin'] = '비타민 A와 비타민 E는 적게 섭취'

# %%
filtered_rows7 = filtered_rows7[~filtered_rows7['contents_origin'].str.contains('녹차는 혈전 생성을 억제하고 동맥경화를 예방하는 작용을 합니다. 따라서 항응고제 복용시 녹차를 꾸준히 복용하려면 항응고제의 용량을 낮추어야 해요.')]

# %%
filtered_rows7
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 521       15366                  레파글리니드(Repaglinide)
# 522       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 523       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 524       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 526       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows7.to_csv('C:/Users/User/filtered_rows8.csv', index=False)

# %%
filtered_rows8 = pd.read_csv(r'C:/Users/User/filtered_rows8.csv')

# %%
filtered_rows8
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 462       15366                  레파글리니드(Repaglinide)
# 463       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 464       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 465       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
# 466       15410  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                                        contents_origin ingd_code
# 0                                           카페인 복용시 주의   I002684
# 1                          마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                            비타민 B의 고갈   I002684
# 3                                            칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('충분한 물과 함께 취침 전에 복용하세요. \[약 250ml 이상\]')]

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('이 약의 장용코딩\(장에서 녹게 하기 위함\)을 보호하기 위해 복용 후 1시간 이내에 칼슘, 마그네슘 보충제를 드시지 마세요. ')]

# %%
filtered_rows8['contents_origin'].str.contains('이 약의 장용코딩\(장에서 녹게 하기 위함\)을 보호하기 위해 복용 후 1시간 이내에 칼슘, 마그네슘 보충제를 드시지 마세요. ')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 462    False
# 463    False
# 464    False
# 465    False
# 466    False
# Name: contents_origin, Length: 465, dtype: bool

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('이 약 복용 30분 이내에 눕지 마세요. 위장관을 자극하거나 식도벽에 궤양을 초래할 수 있어요.')]

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('이 약 복용 60분 이내에 눕지 마세요. 위장관을 자극하거나 식도벽에 궤양을 초래할 수 있어요.')]

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('위산이 부족한 경우, 콜라와 함께 복용하면 이 약의 흡수에 도움이 될 수 있어요.')]

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('칼슘 또는 마그네슘 보충제 복용시 이 약 복용 최소 1시간 이전 또는 2시간 이후에 복용하세요.')]

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('음식과 관계없이 복용할 수 있어요. 위장장애가 생기면 음식과 함께 또는 식후 복용하세요.')]

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('충분한 음식물과 함께 복용하면 이 약의 흡수율을 높일 수 있어요.')]

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('식사와 관계없이 매일 일정한 시간에 복용하세요.')]

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('경구피임제는 체내 엽산을 감소시킬 수 있어요. 엽산 보충제 복용이 도움을 줄 수 있어요.')]

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('경구용 판크레아틴 제제에 의해 엽산의 흡수가 감소될 수 있어요.')]

# %%
filtered_rows8.loc[filtered_rows8['contents_origin'].str.contains('비타민 C와 함께 복용하시면 철분의 흡수가 잘됩니다'), 'contents_origin'] = '비타민 C와 복용하면 철분 흡수 향상'

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('음식물은 이 약의 흡수를 방해하기 때문에, 충분한 흡수를 위해 아침식사 최소 30분 전에 복용하거나 또는 하루 중에 어떤 때라도 음식물이나 음료수의 섭취 전후로 최소 2시간 떨어져서 복용하세요.')]

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('이 약은 식사 직전\(식사 30분 이전 ~ 식사 직전\)에 복용하고 식사를 거를 시에는 이 약도 복용하지 않아요.')]

# %%
filtered_rows8.loc[filtered_rows8['contents_origin'].str.contains('위장장애를 줄이고 적절한 약의 흡수를 위해 식사 초기에 복용하세요. 단, 고지방식이와 같이 복용하면 클라불린산의 흡수를 떨어뜨릴 수 있으므로 피하세요.'), 'contents_origin'] = '고지방식과 같이 복용하면 흡수 저하'

# %%
filtered_rows8.loc[filtered_rows8['contents_origin'].str.contains('자몽주스와 함께 복용하면 이 약의 흡수를 크게\(2배 가량\) 높일 수 있으므로 자몽주스 섭취를 피하세요.'), 'contents_origin'] = '자몽쥬스 섭취 피하기'

# %%
filtered_rows8.loc[filtered_rows8['contents_origin'].str.contains('이 약은 체내 칼륨을 증가시킬 수 있어요. 과량의 \{\{칼륨을 포함하는 식단\}\}을 피하세요. 체내 칼륨이 지나치게 많아지면 심박이 불규칙해질 수 있어요. '), 'contents_origin'] = '과량 칼륨 식단 피하기'

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('이 약은 혈중 칼슘 농도를 증가시킬 수 있어요. 칼슘보충제를 복용하기 전에 의사 또는 약사와 상의하세요.')]

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('음식과 관계없이 복용할 수 있지만 사과/오렌지/자몽주스와 같은 과일주스와는 함께 복용하지 마세요. 과일주스는 약물의 생체이용률을 36%까지 떨어뜨릴 수 있어요. ')]

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('식사와 함께 복용하세요. 식사를 할 수 없는 경우에는 경구용 영양보충제와 함께 복용시 약물의 적정 흡수가 이루어져요.')]

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('식사와 관계없이 매일 일정한 시간에 복용하세요.')]

# %%
filtered_rows8.loc[filtered_rows8['contents_origin'].str.contains('매일 과하지 않은 일정한 양의 \{\{비타민 K\}\}를 섭취하세요. 식사 시 푸른 잎채소\(예. 시금치, 케일 등\)의 섭취량이 급변화하지 않도록 주의하세요. '), 'contents_origin'] = '비타민 K 섭취'

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('코엔자임 Q10은 혈액응고효과가 있어, 복용시 이 약의 효과가 약간 떨어질 수 있어요. 복용시 전문가와 상의한 후 늘 일정량을 복용하도록 주의하세요. ')]

# %%
filtered_rows8.loc[filtered_rows8['contents_origin'].str.contains('감귤주스 또는 비타민 C를 대량 섭취 시 이 약의 흡수가 저해될 수 있어요.'), 'contents_origin'] = '비타민C 대량 섭취 피하기'

# %%
filtered_rows8.loc[filtered_rows8['contents_origin'].str.contains('자몽주스 섭취를 피하세요. 이 약의 혈중농도가 위험한 수준으로 증가할 수 있어요.'), 'contents_origin'] = '자몽주스 섭취 피하기'

# %%
filtered_rows8.loc[filtered_rows8['contents_origin'].str.contains('양파를 과도하게 섭취시 와파린과 상승작용을 일으킬 수 있으므로 주의하세요.'), 'contents_origin'] = '양파 과도한 섭취 주의'

# %%
filtered_rows8.loc[filtered_rows8['contents_origin'].str.contains('크랜베리를 함유한 식품, 고추나물의 복용에 주의하세요.'), 'contents_origin'] = '크랜베리, 고추나물 복용 주의'

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('철분제를 복용시 위장자극이 심해져 위장관 출혈의 위험성이 커질 수 있으니 주의하세요. ')]

# %%
filtered_rows8.loc[filtered_rows8['contents_origin'].str.contains('기타 혈전 방지 효과가 있는 물질\(쏘팔메토, 비타민 E, 비타민 A, 녹차, 말차, 두유\)은 출혈의 위험성을 높일 수 있으니 과량 섭취에 주의하세요. 비타민 E는 하루 400IU 이하, 비타민 A는 하루 10000IU 이하의 섭취량이 적당할 수 있어요. '), 'contents_origin'] = '쏘팔메토, 비타민 E, 비타민 A, 녹차, 말차, 두유 섭취 주의'

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('트립토판 보충제의 복용을 피하세요. 세로토닌 증후군\(빈맥, 떨림, 고혈압, 근육강직 등\)의 위험성이 높아져요.')]

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('과식에 주의하세요.')]

# %%
filtered_rows8 = filtered_rows8[~filtered_rows8['contents_origin'].str.contains('적어도 식사와 2시간의 시간간격을 두고 이 약을 복용하세요. 다른 약이나 건강보조식품 복용시에도 적어도 2시간 먼저 이 약을 복용하세요.')]

# %%
filtered_rows8.loc[filtered_rows8['contents_origin'].str.contains('이 약의 복용으로 칼슘 또는 비타민 D의 혈중농도가 저하될 수 있어요. 칼슘 또는 비타민 D를 함유한 보충제의 복용으로 도움을 줄 수 있어요. '), 'contents_origin'] = '칼슘, 비타민 D의 섭취 권장'

# %%
filtered_rows8
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 461       15365                  레파글리니드(Repaglinide)
# 462       15366                  레파글리니드(Repaglinide)
# 463       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 464       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 465       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                              contents_origin ingd_code
# 0                                 카페인 복용시 주의   I002684
# 1                마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                  비타민 B의 고갈   I002684
# 3                                  칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows8.to_csv('C:/Users/User/filtered_rows9.csv', index=False)

# %%
filtered_rows9 = pd.read_csv(r'C:/Users/User/filtered_rows9.csv')

# %%
filtered_rows9
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 414       15365                  레파글리니드(Repaglinide)
# 415       15366                  레파글리니드(Repaglinide)
# 416       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 417       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 418       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                              contents_origin ingd_code
# 0                                 카페인 복용시 주의   I002684
# 1                마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                  비타민 B의 고갈   I002684
# 3                                  칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('이 약을 위\(stomach\)로 쉽게 도달시키고 식도자극 가능성을 감소시키기 위해, 똑바른 자세\(upright position\)로 충분한 양의 순수한 물\(170 ∼ 240 mL\)과 함께 복용하세요. 광천수나 보리차를 포함하여 다른 음료수와 함께 복용시 이 약의 흡수를 떨어뜨릴 수 있어요. ')]

# %%
filtered_rows9
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 414       15365                  레파글리니드(Repaglinide)
# 415       15366                  레파글리니드(Repaglinide)
# 416       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 417       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 418       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                              contents_origin ingd_code
# 0                                 카페인 복용시 주의   I002684
# 1                마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                  비타민 B의 고갈   I002684
# 3                                  칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('식사와 관계없이 하루 중 어느 때나 복용할 수 있어요. ')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('흡수를 높이기 위해 식사와 함께 복용하세요.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('위장의 산도가 낮으면 이 약의 생체이용률이 크게 떨어질 수 있어요. 생체이용률을 높이기 위해 반드시 식사와 함께 또는 식후 즉시 복용하세요. ')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('마그네슘\(Mg\) 보충제를 복용하실 경우,  2시간 이상 간격을 두세요.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('칼슘\(Ca\) 보충제를 복용하실 경우,  2시간 이상 간격을 두세요.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('제산제를 복용할 경우, 2시간 이상 간격을 두세요.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('천연진정제\(예. 카바, 호프, 길초근, 시계꽃\)를 복용시 약효가 중복되므로 위험할 수 있어요.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('니코틴은 이 약의 배설을 촉진하여 약효를 감소시킬 수 있어요.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('위장장애를 줄이기 위해 식후 또는 음식/우유와 함께 드세요.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('경구제제 : 칼슘/비타민 D 보충제 섭취를 피하세요.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('연고제제 : 칼슘/비타민 D 보충제와 함께 복용에 주의하세요.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('에키나시아 복용에 주의하세요. 에키나시아와 이 약을 함께 복용시 신체 면역 기능에 부정적인 영향을 미칠 수 있어요.')]

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('비타민 B12 는 이 약의 효과를 저해할 수 있어요. '), 'contents_origin'] = '비타민 B는 약 효과 저해'

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('제산제 복용시 이 약의 흡수가 저하되어 치료효과가 감소할 수 있어요.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('이 약을 복용하는 동안 입이 마를 수 있어요. 충분한 물을 자주 복용하세요.')]

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('이 약을 장기복용시 혈중 칼슘 또는 비타민 D의 농도가 낮아질 수 있어요. 칼슘 또는 비타민 D 보충제의 복용이 도움이 될 수 있어요.  '), 'contents_origin'] = '칼슘 비타민 D 권장'

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('이 약을 복용시 혈중 엽산 농도가 낮아질 수 있어요. 엽산 보충제의 복용이 도움이 될 수 있어요.'), 'contents_origin'] = '엽산 권장'

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('임산부가 이 약을 복용시 신생아는 심각한 비타민 K의 부족이 있을 수 있어요. 분만 전 임산부의 비타민 K 보충을 권해요.')]

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('철분은 이 약의 흡수를 1/10까지 감소시키므로 함께 복용하지 마세요. 함께 복용할 경우, 이 약과 3시간 이상의 시간간격을 두세요.'), 'contents_origin'] = '철분과 함께 복용 금지'

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('제산제\(알루미늄 또는 마그네슘 제제\)는 이 약의 흡수를 저해하여 효과가 감소될 수 있어요. 함께 복용할 경우, 이 약 투여 후 2시간 이상 간격을 두세요.')]

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('브로콜리, 순무, 콜리플라워 등은 이 약의 혈중농도를 감소시킬 수 있어요. 의사 또는 약사에게 알리고 매일 일정한 양을 섭취하도록 식단을 조절하면 좋아요. '), 'contents_origin'] = '브로콜리, 순무, 콜리플라워 적게 섭취'

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('혈액 중에 칼륨농도를 높일 수 있으므로 칼륨보충제나 염대체제, \{\{칼륨이 풍부한 식이요법\}\}시 전문가와 상의하세요.'), 'contents_origin'] = '칼륨 적게 섭취'

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('레드와인 섭취 시 약효가 감소될 수 있으므로 주의하세요.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('적어도 식사 1시간 전에 이 약을 복용하세요. 다른 약이나 건강보조식품 복용시에도 적어도 1시간 먼저 이 약을 복용하세요.')]

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('과량의 \{\{티라민\}\} 섭취에 주의하세요. 갑작스러운 혈압상승으로 위험할 수 있어요. '), 'contents_origin'] = '과량의 티라민 섭취 주의'

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('히스타민 함유 음식\(예. 가다랑어, 참치\) 섭취 시 주의하세요. 두통, 발한, 심박상승의 부작용이 발생할 수 있어요.'), 'contents_origin'] = '가다랑어, 참치 섭취 주의'

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('피리독신 보충제가 도움이 될 수 있어요.')]

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('고지방음식이나 우유와 함께 복용하시면 흡수가 더 잘 됩니다.  다량의 물과 함께 복용하면 위장장애를 줄일 수 있어요.'), 'contents_origin'] = '고지방음식 섭취 권장'

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('비타민 A 보충제 복용에 주의하세요. 이 약의 부작용이 심해질 수 있어요.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('천연진정제\(예. 카바, 호프, 길초근, 시계꽃\)와 약효가 중복되므로 복용에 주의하세요.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('니코틴은 이 약의 배설을 촉진하여 약효를 감소시킬 수 있어요.')]

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('대량의 자몽주스 섭취에 주의하세요.'), 'contents_origin'] = '자몽주스 섭취에 주의'

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('적절한 수분섭취/공급이 필요합니다.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('엽산 보충제는 이 약의 효과를 저해할 수 있어요.')]

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('고탄수화물 식품은 약의 필요 용량 증가'), 'contents_origin'] = '고탄수화물 식품 섭취 주의'

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('\{\{칼륨\}\}, 마그네슘 섭취를 높이거나 보충제를 복용하고, 칼슘과 나트륨 섭취를 줄이는 것이 좋습니다.'), 'contents_origin'] = '칼륨, 마그네슘 섭취 권장, 칼슘,나트륨 섭취 주의'

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('이 약의 투여기간 중 및 투여 후 3일간은 꼭 금주하세요. 디설피람양 반응으로 심한 오심, 구토, 두통 등의 부작용을 유발할 수 있어요.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('주사제제 : 구역/구토가 생길 수 있으므로 이 약을 주사하기 4-6시간 전부터는 식사나 수분 섭취를 제한하세요.')]

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('이 약은 지방을 함유하는 식사와 함께 또는 식사 후 1시간 이내에 복용하고, 식사를 거르거나 지방을 함유하지 않은 식사를 할 시에는 이 약도 복용하지 않아요. '), 'contents_origin'] = '지방을 함유하는 식사해야함'

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('지용성 비타민\(비타민 A, D, E, K, 베타케로틴\)의 결핍이 나타날 수 있지만 이를 함유한 보충제\(종합비타민제 등\)를 병용하면 도움이 될 수 있어요. 이 때 보충제는 이 약 복용 2시간 이전 또는 2시간 이후, 또는 취침전에 복용할 수 있어요.'), 'contents_origin'] = '비타민 A,D,E,K 권장'

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('이 약의 투여기간 중 및 투여 후 3일간은 꼭 금주하세요. 디설피람양 반응으로 심한 오심, 구토, 두통 등의 부작용을 유발할 수 있어요.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('약물농도가 떨어질 수 있으므로 에키나시아와 같이 복용시 주의하세요.')]

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('마늘과 멜라토닌은 이 약의 대사를 저해하므로, 이 약의 혈중농도를 증가시켜 부작용을 악화시킬 수 있어요.'), 'contents_origin'] = '마늘, 멜라토닌 금지'

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('이 약의 투여기간 동안 다량의 자몽주스 섭취를 피하세요. 이 약의 혈압강하효과가 불규칙하게 증강될 수 있어요.'), 'contents_origin'] = '자몽주스 섭취 금지'

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('인삼 복용에 주의하세요. 혈압상승의 위험성이 있어요.'), 'contents_origin'] = '인삼 복용 주의'

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('식사 또는 보충제를 통한 충분한 칼슘 및 비타민 D의 섭취가 권장되요.'), 'contents_origin'] = '칼슘, 비타민 D 섭취 권장'

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('이 약을 우유 및 유제품과 함께 복용하지 마세요. 우유 및 유제품 섭취 시에는 이 약과 최소 2시간의 시간간격을 두고 섭취하세요.')]

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('과량 칼륨 식단 피하기'), 'contents_origin'] = '칼륨 식단 피하기'

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('마늘과 멜라토닌은 이 약의 대사를 저해하므로, 이 약의 혈중농도를 증가시켜 부작용을 악화시킬 수 있어요.'), 'contents_origin'] = '마늘과 멜라토닌 주의'

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('현탁액 : 흡수율을 높이기 위해 음식과 함께 또는 식후 복용하세요. ')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('다른 의약품 복용 최소 3시간 이전 또는 1시간 이후에 이 약을 복용하세요.')]

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('이 약은 비타민 K의 효과를 상쇄시킬 수 있어요.'), 'contents_origin'] = '비타민 K 권장'

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('이 약은 비타민 D의 고갈을 일으킬 수 있어요. 보충제의 복용이 도움을 줄 수 있어요.'), 'contents_origin'] = '비타민 D 권장'

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('과량의 산성식품\(예. 밀가루, 계란, 생선, 육류 등\) 섭취에 주의하세요. 요의 알칼리화는 이 약의 배설을 저해할 수 있어요.'), 'contents_origin'] = '밀가루, 계란, 생선, 육류 주의'

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('이 약은 담즙산과 결합하므로 정상적인 지방의 소화와 흡수를 방해하여 비타민 A, D, K와 같은 지용성 비타민과 엽산의 흡수를 저해할 수 있습니다. 장기간 복용시에는 물에 혼합되는 지용성비타민제제\(또는 비경구 형태\)를 공급해 주세요. 또한 이러한 보충제는 반드시 이 약을 복용하기 1시간 전 또는 4시간 이후에 복용/투여하세요.')]

# %%
filtered_rows9 = filtered_rows9[~filtered_rows9['contents_origin'].str.contains('건조시럽, 정제 : 식사와 관계없이 복용하거나, 위장장애를 줄이기 위해 식후 복용할 수 있어요.')]

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('중추신경을 자극하는 인삼, 마황, 감초뿌리 복용에 주의하세요. 혈압상승의 위험성이 있어요. '), 'contents_origin'] = '인삼, 마황, 감초뿌리 복용에 주의'

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('마늘, 생강, 인삼, 은행엽은 과량 섭취에 주의'), 'contents_origin'] = '마늘, 생강, 인삼, 은행엽 섭취 주의'

# %%
filtered_rows9.loc[filtered_rows9['contents_origin'].str.contains('고지방/고탄수화물 식사는 이 약의 혈중농도를 60% 정도 높일 수 있습니다. 공복 또는 가벼운 저지방식사 후에 복용하세요.'), 'contents_origin'] = '고지방, 고탄수화물 주의'

# %%
filtered_rows9
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 414       15365                  레파글리니드(Repaglinide)
# 415       15366                  레파글리니드(Repaglinide)
# 416       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 417       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 418       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                              contents_origin ingd_code
# 0                                 카페인 복용시 주의   I002684
# 1                마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                  비타민 B의 고갈   I002684
# 3                                  칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows9.to_csv('C:/Users/User/filtered_rows10.csv', index=False)

# %%
filtered_rows10 = pd.read_csv(r'C:/Users/User/filtered_rows10.csv')

# %%
filtered_rows10
# Out:
#      Unnamed: 0                            sunb_name  \
# 0            11                    오메프라졸(Omeprazole)
# 1            12                    오메프라졸(Omeprazole)
# 2            13                    오메프라졸(Omeprazole)
# 3            14                    오메프라졸(Omeprazole)
# 4            19          탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                  ...
# 355       15365                  레파글리니드(Repaglinide)
# 356       15366                  레파글리니드(Repaglinide)
# 357       15376     파조파닙염산염(Pazopanib Hydrochloride)
# 358       15407  티클로피딘염산염(Ticlopidine Hydrochloride)
# 359       15408  티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                              contents_origin ingd_code
# 0                                 카페인 복용시 주의   I002684
# 1                마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                                  비타민 B의 고갈   I002684
# 3                                  칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('이 약을 장기복용시 혈중 칼슘 또는 비타민 D의 농도가 낮아질 수 있어요. 칼슘 또는 비타민 D 보충제의 복용이 도움이 될 수 있어요. '), 'contents_origin'] = '칼슘, 비타민D 섭취 권장'

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('칼슘 또는 마그네슘을 함유한 제산제 또는 보충제를 복용시 이 약 복용 최소 2시간 이전 또는 4시간 이후에 복용하세요. ')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('흡수를 높이고 위장장애를 줄이기 위해 식사와 함께 또는 식후 즉시 복용하세요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('반드시 식사/음식과 함께 복용하세요. ')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('위장장애를 줄이기 위해 식후 또는 음식과 함께 드실 수 있어요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('식사와 관계없이 복용하거나, 위장장애를 줄이기 위해 식후 복용할 수 있어요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('첫 식사 30분 전에 복용하세요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('제산제\(인산알루미늄 함유\) 복용시 이 약의 흡수가 저해될 수 있어요. 이 약과 시간간격을 두고 제산제를 복용하세요.')]

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('식단 조절에 유의하세요. 고지방식이\(섭취하는 총 열량의 30% 이상이 지방열량\) 시 이 약의 부작용이 심해질 수 있어요. '), 'contents_origin'] = '고지방 함유 음식 피하기'

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('고지방식이는 이 약의 흡수와 혈중농도를 높여 약의 작용 및 부작용에 영향을 미칠 수 있어요.'), 'contents_origin'] = '고지방 함유 음식 피하기'

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('칼슘, 마그네슘, 알루미늄 함유 제산제 또는 칼슘, 마그네슘, 철, 아연 함유 보충제 복용시 이 약의 흡수가 저해될 수 있어요. 이 약과 최소 2시간의 시간간격을 두고 복용하세요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('칼슘 또는 마그네슘 보충제 복용시 이 약의 흡수가 저해될 수 있어요.')]

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains(' 자몽주스는 이 약의 흡수와 혈중농도를 낮출 수 있으므로 피하세요.'), 'contents_origin'] = '자몽주스 섭취 피하기'

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('알루미늄 포함 제산제, 칼슘이 풍부한 음식 \(예, 유제품, 칼슘보강주스\), 또는 철분, 칼슘, 알루미늄, 마그네슘, 셀레늄, 아연과 같은 다가 양이온을 포함한 보충제는 최소 4시간의 간격을 두고 투여하세요.'), 'contents_origin'] = '고 칼륨 음식섭취 피하기'

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('제산제를 복용시, 제산제 복용 최소 1시간 이전에 이 약을 복용하세요. ')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('식사 또는 우유와 함께 복용하면 위장장애를 줄일 수 있어요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('식사와 함께 복용하세요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('식사바로 직전이나 식사와 함께 복용하세요.')]

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('자몽주스 섭취를 피하세요. 이 약의 혈중농도가 상승할 수 있어요.'), 'contents_origin'] = '자몽주스 섭취 피하기'

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('알루미늄 또는 마그네슘을 함유한 제산제 복용시 주의하세요. 이 약의 혈중농도가 상승할 수 있어요.')]

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('이 약은 체내 칼륨을 증가시킬 수 있어요. \{\{칼륨이 풍부한 식단\}\} 또는 칼륨보충제를 피하세요. 고칼륨혈증의 위험성이 커져요.'), 'contents_origin'] = '고칼륨 음식 섭취 피하기'

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('약효를 높이기 위해 식후에 복용하세요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('식사와 함께 복용하세요. 음식물과 함께 복용시 이 약의 흡수율을 2배 정도 높일 수 있어요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('위장장애를 줄이기 위해 식후 또는 음식과 함께 드실 수 있어요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('식사 최소 1시간 이전 또는 1시간 이후에 일정한 규칙을 가지고 이 약을 복용하세요. 개인의 변동성을 최소화하기 위하여 식사와 관련한 이 약의 투여를 표준화하는 것이 중요해요.\(예, 라파티닙을 항상 식사 1시간 이전에 복용합니다.\)')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('칼슘, 마그네슘, 알루미늄 함유 제산제 또는 칼슘, 마그네슘, 철, 아연 함유 보충제 복용시 이 약의 흡수가 저해될 수 있어요. 이 약과 최소 2시간의 시간간격을 두고 복용하세요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('제산제\(인산알루미늄 함유\) 복용시 이 약의 흡수가 저해될 수 있어요. 이 약과 시간간격을 두고 제산제를 복용하세요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('서방제제 : 레드와인과 섭취 시 약물이 과량방출될 수 있으므로 주의하세요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('식사와 다량의 물과 함께 복용하면 위장장애를 줄일 수 있어요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('제산제를 복용시, 제산제 복용 최소 1시간 이전에 이 약을 복용하세요. ')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('식사와 무관하게 복용할 수 있으며 물과 함께 씹지말고 삼키세요.')]

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('취침전에 복용하세요. 지방함량이 높거나 많은 양의 식사 후에는 복용하지 마세요. 약효가 떨어질 수 있어요.'), 'contents_origin'] = '지방함량이 높은 음식 섭취 피하기'

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('식사 1시간 전에 복용하세요.')]

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('감초를 많이 섭취하지 마세요. 감초캔디\(감초트위스트\)를 하루에 2~3개 이상 섭취할 경우, 코티솔 농도가 높아지고 나트륩 재흡수, 칼륨 배설이 높아져 항고혈압약의 효과를 방해할 수 있습니다.'), 'contents_origin'] = '감초 섭취 피하기'

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('10mg 은 식사와 관계없이 복용하고, 15mg 및 20mg 은 식사와 함께 복용하세요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('Acarbose는 음식물 중 탄수화물의 분해와 흡수를 지연시키는 약으로, 이 약은 식사 바로 직전이나 식사 첫 숟갈과 함께 복용하면 최적의 효과가 나타날 수 있어요.')]

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('감자, 흰 빵 등과 같은 고탄수화물 식품은 혈당수준을 상승시켜 이 약의 필요 용량을 증가시킬 수 있어요. '), 'contents_origin'] = '고탄수화물 음식 섭취 피하기'

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('이 약은 엽산의 고갈을 일으킬 수 있어요. 보충제의 복용이 도움을 줄 수 있어요.'), 'contents_origin'] = '엽산 권장'

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('제산제를 복용시 이 약의 흡수가 저해될 수 있어요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('칼륨 보충제를 복용시 주의하세요. 고칼륨혈증의 위험성이 커질 수 있어요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('마그네슘, 철분, 아연 또는 칼슘 보충제 복용시 이 약 복용 최소 3시간 이전 또는 2시간 이후에 복용하세요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('칼슘 보충제와 함께 복용을 피하세요.')]

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('이 약은 체내 칼륨을 증가시킬 수 있어요. \{\{칼륨이 풍부한 식단\}\} 또는 칼륨보충제를 피하세요. 고칼륨혈증의 위험성이 커져요.'), 'contents_origin'] = '고칼륨 음식 섭취 피하기'

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('칼슘보충제나 비타민 D 보충제를 복용하기 전에 반드시 전문가와 상의하세요\(고칼슘혈증 가능성\). '), 'contents_origin'] = '칼슘, 비타민 D 섭취 피하기'

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('과도한 식이섬유의 섭취는 이 약의 흡수를 방해할 수 있어요. 식이섬유가 풍부한 식단을 섭취 시에는 이 약과 2시간 이상의 간격을 두세요.'), 'contents_origin'] = '과도한 식이섬유 섭취 피하기'

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('감초 뿌리\(글리시리진\) 복용시 불규칙적인 심박과 심장마비를 초래할 위험성이 커져요. 섭취에 주의하세요.'), 'contents_origin'] = '감초뿌리 섭취 주의'

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('칼륨 보충제를 복용시 주의하세요. 고칼륨혈증의 위험성이 커질 수 있어요.')]

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('풍부한 \{\{칼륨\}\}, 낮은 나트륨, 적절한 마그네슘과 칼슘섭취를 유지하세요.'), 'contents_origin'] = '칼륨 다량 섭취, 나트륨 소량 섭취, 마그네슘과 칼슘섭취 필요'

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('효과를 높이기 위해 식후에 복용하세요.')]

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('고지방식사와 함께 복용하면 흡수율이 떨어질 수 있어요.'), 'contents_origin'] = '고지방식사 피하기'

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('멜라토닌은 이 약의 대사를 낮추어 약물농도를 높일 수 있습니다.'), 'contents_origin'] = '멜라토닌 피하기'

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('이 약을 우유 및 유제품과 함께 복용하지 마세요. 우유 및 유제품 섭취 시에는 이 약과 최소 2시간의 시간간격을 두고 섭취하세요.'), 'contents_origin'] = '유제품 피하기'

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('방광염을 예방하기 위해 복용 전과 복용 후 적어도 72시간 동안은 충분한 수분을 섭취하세요. 하루에 2-3리터 복용하여 충분히 소변으로 배출되도록 하세요. ')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('이 약을 우유 및 유제품, 칼슘 강화 주스와 단독으로 복용하지 마세요. 칼슘이 이 약의 흡수를 방해하여 약효가 감소할 수 있어요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('신장\(콩팥\)보호를 위해 충분한 수분을 섭취하세요: 24시간 동안 2리터의 소변이 배출될 수 있도록 하루에 2.5-3리터의 수분을 섭취하세요.')]

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('철분제와는 적어도 2~3시간의 간격을 두고 복용하세요. 이 약은 철분과 결합\(킬레이트 형성\)할 수 있어요. '), 'contents_origin'] = '철분 피하기'

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('중추신경을 자극하는 인삼, 마황, 감초뿌리 복용에 주의하세요. 혈압상승의 위험성이 있어요. '), 'contents_origin'] = '인삼, 마황, 감초뿌리 복용에 주의'

# %%
filtered_rows10.loc[filtered_rows10['contents_origin'].str.contains('마황 함유 식품의 섭취를 삼가세요. 마황은 심장박동을 증가시키고 혈압을 상승시키는 작용이 있어 이 약과 함께 복용시 위험할 수 있어요.'), 'contents_origin'] = '마황 함유 식품 복용에 주의'

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('식사와 함께 복용하면 이 약의 흡수율이 높아질 수 있어요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('식사 15분 전\(식사 30분 이전부터 식사 직전\)에 복용하세요.')]

# %%
filtered_rows10 = filtered_rows10[~filtered_rows10['contents_origin'].str.contains('이 약은 식사를 할 시 복용하고, 식사를 거를 시에는 복용하지 않아요.')]

# %%
filtered_rows10
# Out:
#      Unnamed: 0                                  sunb_name  \
# 0            11                          오메프라졸(Omeprazole)
# 1            12                          오메프라졸(Omeprazole)
# 2            13                          오메프라졸(Omeprazole)
# 3            14                          오메프라졸(Omeprazole)
# 4            19                탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                        ...
# 352       15316  메틸페니데이트염산염(Methylphenidate Hydrochloride)
# 353       15317  메틸페니데이트염산염(Methylphenidate Hydrochloride)
# 357       15376           파조파닙염산염(Pazopanib Hydrochloride)
# 358       15407        티클로피딘염산염(Ticlopidine Hydrochloride)
# 359       15408        티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                  contents_origin ingd_code
# 0                     카페인 복용시 주의   I002684
# 1    마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                      비타민 B의 고갈   I002684
# 3                      칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows10.to_csv('C:/Users/User/filtered_rows11.csv', index=False)

# %%
filtered_rows11 = pd.read_csv(r'C:/Users/User/filtered_rows11.csv')

# %%
filtered_rows11
# Out:
#      Unnamed: 0                                  sunb_name  \
# 0            11                          오메프라졸(Omeprazole)
# 1            12                          오메프라졸(Omeprazole)
# 2            13                          오메프라졸(Omeprazole)
# 3            14                          오메프라졸(Omeprazole)
# 4            19                탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                        ...
# 308       15316  메틸페니데이트염산염(Methylphenidate Hydrochloride)
# 309       15317  메틸페니데이트염산염(Methylphenidate Hydrochloride)
# 310       15376           파조파닙염산염(Pazopanib Hydrochloride)
# 311       15407        티클로피딘염산염(Ticlopidine Hydrochloride)
# 312       15408        티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                  contents_origin ingd_code
# 0                     카페인 복용시 주의   I002684
# 1    마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                      비타민 B의 고갈   I002684
# 3                      칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows11 = filtered_rows11[~filtered_rows11['contents_origin'].str.contains('알로에')]

# %%
filtered_rows11 = filtered_rows11[~filtered_rows11['contents_origin'].str.contains('충분한 물과 함께 드세요.')]

# %%
filtered_rows11 = filtered_rows11[~filtered_rows11['contents_origin'].str.contains('식사와 함께, 또는 식후 복용하세요. ')]

# %%
filtered_rows11 = filtered_rows11[~filtered_rows11['contents_origin'].str.contains('이 약을 복용하는 동안 충분한 수분을 섭취하세요.')]

# %%
filtered_rows11.loc[filtered_rows11['contents_origin'].str.contains('자몽주스 섭취를 피하세요. 이 약의 혈중농도를 상승시켜 부작용이 심해져요.'), 'contents_origin'] = '자몽주스 섭취를 피하세요'

# %%
filtered_rows11
# Out:
#      Unnamed: 0                                  sunb_name  \
# 0            11                          오메프라졸(Omeprazole)
# 1            12                          오메프라졸(Omeprazole)
# 2            13                          오메프라졸(Omeprazole)
# 3            14                          오메프라졸(Omeprazole)
# 4            19                탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                        ...
# 308       15316  메틸페니데이트염산염(Methylphenidate Hydrochloride)
# 309       15317  메틸페니데이트염산염(Methylphenidate Hydrochloride)
# 310       15376           파조파닙염산염(Pazopanib Hydrochloride)
# 311       15407        티클로피딘염산염(Ticlopidine Hydrochloride)
# 312       15408        티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                  contents_origin ingd_code
# 0                     카페인 복용시 주의   I002684
# 1    마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                      비타민 B의 고갈   I002684
# 3                      칼슘 흡수를 저해   I002684
# ...

# %%
filtered_rows11.to_csv('C:/Users/User/filtered_rows12.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 filtered_rows11.to_csv('C:/Users/User/filtered_rows12.csv', index=False)
#
# NameError: name 'filtered_rows11' is not defined

# %%
pd.read_csv(r'C:/Users/User/filtered_rows12.csv')
# Out:
#      Unnamed: 0                                  sunb_name  \
# 0            11                          오메프라졸(Omeprazole)
# 1            12                          오메프라졸(Omeprazole)
# 2            13                          오메프라졸(Omeprazole)
# 3            14                          오메프라졸(Omeprazole)
# 4            19                탄산수소나트륨(Sodium Bicarbonate)
# ..          ...                                        ...
# 303       15316  메틸페니데이트염산염(Methylphenidate Hydrochloride)
# 304       15317  메틸페니데이트염산염(Methylphenidate Hydrochloride)
# 305       15376           파조파닙염산염(Pazopanib Hydrochloride)
# 306       15407        티클로피딘염산염(Ticlopidine Hydrochloride)
# 307       15408        티클로피딘염산염(Ticlopidine Hydrochloride)
#
#                  contents_origin ingd_code
# 0                     카페인 복용시 주의   I002684
# 1    마늘, 양파 등 자극성이 강한 식품은 섭취에 주의   I002684
# 2                      비타민 B의 고갈   I002684
# 3                      칼슘 흡수를 저해   I002684
# ...
